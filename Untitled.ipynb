# %%
import matplotlib.pyplot as plt

# Data
rows = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 794, 1589, 2384, 3153, 4743, 6306, 7697]
no_aggregates = [0.0214, 0.0344, 0.0378, 0.0524, 0.066, 0.0958, 0.106, 0.2614, 0.476, 0.7952, 1, 1.6, 2, 4, 6, 7, 9]
aggregates = [0.0144, 0.0164, 0.0186, 0.0176, 0.0206, 0.0242, 0.0224, 0.0266, 0.0236, 0.099, 0.0392, 0.0558, 0.0602, 0.0844, 0.1, 0.1246, 0.15]
rows = [1000*row for row in rows]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rows, no_aggregates, marker='o', label='No Aggregates')
plt.plot(rows, aggregates, marker='o', label='With Aggregates')
plt.xlabel('Rows')
plt.ylabel('Average Time (s)')
plt.title('Performance Comparison: No Aggregates vs. With Aggregates (Ordered Data)')
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.savefig('Validation1.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the new image (No Aggregates, No Ordering)
rows = [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 794, 1589, 2384, 3153, 4743, 6306, 7697]
no_aggregates_no_ordering = [0.0254, 0.0322, 0.0488, 0.0784, 0.1224, 0.2828, 0.6346, 0.4546, 1, 0.7952, 1, 1.6, 2, 4, 6, 7, 9]
aggregates_no_ordering = [0.0126, 0.014, 0.0128, 0.0146, 0.0166, 0.0136, 0.0138, 0.0166, 0.0188, 0.0318, 0.0204, 0.0466, 0.0466, 0.0644, 0.0646, 0.0966, 0.1186]
rows = [1000*row for row in rows]
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rows, no_aggregates_no_ordering, marker='o', label='No Aggregates, No Ordering')
plt.plot(rows, aggregates_no_ordering, marker='o', label='Aggregates, No Ordering')
plt.xlabel('Rows')
plt.ylabel('Average Time (s)')
plt.title('Performance Comparison: No Aggregates vs. Aggregates (No Ordering)')
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.savefig('Validation2.png')

plt.show()
